# %%
print("Kernel is ready and connection info displayed.")
# Out:
# Kernel is ready and connection info displayed.

# %%
import ipykernel
import json

# Get the connection file path
connection_file = ipykernel.get_connection_file()
print(f"Connection file: {connection_file}")

# Read and display the connection info
with open(connection_file) as f:
    connection_info = json.load(f)

print(json.dumps(connection_info, indent=2))
# Out:
# Connection file: /root/.local/share/jupyter/runtime/kernel-c75de8dc-7c30-48c9-8cf3-ddf7f9a5ba6c.json
# {
#   "shell_port": 1,
#   "iopub_port": 2,
#   "stdin_port": 3,
#   "control_port": 4,
#   "hb_port": 5,
#   "ip": "/root/.local/share/jupyter/runtime/kernel-c75de8dc-7c30-48c9-8cf3-ddf7f9a5ba6c-ipc",
#   "key": "",
#   "transport": "ipc",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
