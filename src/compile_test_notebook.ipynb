# %%
# !git clone https://github.com/NicoSantamaria/cocupy.git
# Out:
# fatal: destination path 'cocupy' already exists and is not an empty directory.

# %%
from cocupy.toolchain.compile_test import write_cuda_file

write_cuda_file("program2.cu", "exec2", num_threads=8, 
                custom_message="Thread ID is")

# %%
# !./exec2
# Out:
# Starting CUDA program...
# Program completed.
